# %% [markdown]
# <a href="https://colab.research.google.com/github/VindiSovia/Analisis_Sentimen/blob/main/Scraping_google_PS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Referensi: https://www.linkedin.com/pulse/how-scrape-google-play-reviews-4-simple-steps-using-python-kundi/

# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
from google_play_scraper import app, Sort, reviews
from datetime import datetime  # Import datetime for date handling

import pandas as pd

import numpy as np

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.lazada.android',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=500, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['reviews'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('reviews').tolist()))

df_busu.head()
# Out:
#                                reviewId        userName  \
# 0  39b311bf-bbf5-4277-842e-7ccbba09950c   khoirul Anwar
# 1  96b41b7e-377b-46c8-b34b-67710f3df4da    it'sme iffaa
# 2  5fa805d4-f301-4f92-9735-3718298b6fbd   Zul Interisti
# 3  e1224cdb-1f2e-482d-bdaf-c98232a4beb7  Setiawan Agung
# 4  01c853f9-6fc4-4c4f-bfa3-d65ec0488862    Ade Fitriani
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  lazada emang aplikasi belanja online paling to...      5           9669
# 1  dari dulu aku selalu pakai lazada untuk belanj...      5            279
# 2  Sangat mengecewakan sekali, 4 paket di pesan s...      1            418
# 3  Barang yang datang rata rata sesuai sama yang ...      3             15
# 4  Game di lazada benar2 menguras data, baru main...      3             23
#
#   reviewCreatedVersion                  at  \
# 0               7.48.0 2024-04-15 08:16:05
# 1               7.53.0 2024-06-24 11:52:09
# 2               7.53.0 2024-06-19 10:03:30
# 3               7.53.0 2024-06-24 22:53:13
# 4               7.51.0 2024-06-24 08:35:53
#
#                                         replyContent           repliedAt  \
# 0  Hi khoirul Anwar, terima kasih untuk ulasan po... 2024-04-15 08:25:22
# 1                                               None                 NaT
# 2  Hi Kak Zul Interisti, kami sampaikan permohona... 2024-06-19 10:46:46
# 3  Hi Setiawan Agung, terima kasih untuk ulasan p... 2023-12-14 11:45:40
# 4                     Thank you for rating our App.  2017-12-29 07:15:24
#
#   appVersion
# 0     7.48.0
# 1     7.53.0
# 2     7.53.0
# 3     7.53.0
# 4     7.51.0

# %%
len(df_busu.index) #count the number of data we got
# Out:
# 500

# %%
df_busu[['userName', 'score','at', 'content']].head()  #preview userName, rating, date-time, and reviews only
# Out:
#          userName  score                  at  \
# 0   khoirul Anwar      5 2024-04-15 08:16:05
# 1    it'sme iffaa      5 2024-06-24 11:52:09
# 2   Zul Interisti      1 2024-06-19 10:03:30
# 3  Setiawan Agung      3 2024-06-24 22:53:13
# 4    Ade Fitriani      3 2024-06-24 08:35:53
#
#                                              content
# 0  lazada emang aplikasi belanja online paling to...
# 1  dari dulu aku selalu pakai lazada untuk belanj...
# 2  Sangat mengecewakan sekali, 4 paket di pesan s...
# 3  Barang yang datang rata rata sesuai sama yang ...
# 4  Game di lazada benar2 menguras data, baru main...

# %%
#Run This Code to Sort the Data By Date

new_df = df_busu[['userName', 'score','at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=True) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#            userName  score                  at  \
# 284  Lia Novitasari      4 2024-01-20 07:34:24
# 280  Ma'mun Anshori      4 2024-02-09 04:12:09
# 286  Andreas Inesta      3 2024-02-20 00:47:45
# 162       bahri ari      4 2024-04-10 02:58:16
# 331    Rangga Putra      3 2024-04-11 03:07:54
#
#                                                content
# 284  Promo dan fitur-fiturnya menarik dan bermanfaa...
# 280  Aku udah make Lazada dari lama, jadi kerasa ba...
# 286  Semenjak di update ke versi lebih tinggi, apli...
# 162  Aplikasi nya lumayan membantu..Harga barang yg...
# 331  Soal aplikasinya bagus, toko² nya pun menarik,...

# %%
df_busu = sorted_df

# %%
df_busu.head()
# Out:
#            userName  score                  at  \
# 284  Lia Novitasari      4 2024-01-20 07:34:24
# 280  Ma'mun Anshori      4 2024-02-09 04:12:09
# 286  Andreas Inesta      3 2024-02-20 00:47:45
# 162       bahri ari      4 2024-04-10 02:58:16
# 331    Rangga Putra      3 2024-04-11 03:07:54
#
#                                                content
# 284  Promo dan fitur-fiturnya menarik dan bermanfaa...
# 280  Aku udah make Lazada dari lama, jadi kerasa ba...
# 286  Semenjak di update ke versi lebih tinggi, apli...
# 162  Aplikasi nya lumayan membantu..Harga barang yg...
# 331  Soal aplikasinya bagus, toko² nya pun menarik,...

# %%
df_busu.to_csv("LazadaGPST.csv", index=False)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cp -R /content/LazadaGPST.csv /content/drive/MyDrive/Skripsi/Dataset/500/GS/LazadaGPST.csv
